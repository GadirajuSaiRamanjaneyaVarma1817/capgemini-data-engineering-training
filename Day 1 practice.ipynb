# %% [markdown]
# ### Read the file from catalog

# %%
df = spark.read.csv("/Volumes/workspace/default/de/C1.csv",header=True,inferSchema=True)

# %%
df.display()

# %% [markdown]
# ### Handle Blank Values

# %%
from pyspark.sql.functions import *
df = df.replace(["blank","Blank"],None)

# %%
df.display()

# %% [markdown]
# ### Fix country columns

# %%
df = df.withColumn("Country",upper(col("Country")))

# %%
df.display()

# %% [markdown]
# ### Fix Date Format

# %% [markdown]
# ### Fill missing values

# %%
df = df.fillna({
    "Category":"Unknown",
    "Sales":0
})

# %%
df.display()

# %% [markdown]
# ### Remove Duplicates

# %%
df = df.dropDuplicates((["Name"]))
df.display()

# %% [markdown]
# ### Save and clean
